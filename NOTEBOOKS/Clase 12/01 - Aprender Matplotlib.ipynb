# %% [markdown]
# # Semana 12 - Aprender Matplotlib
#
# **Propósito de la clase:** aprender a crear gráficos claros con Python y Matplotlib, interpretar lo que muestran y decidir qué tipo de gráfico conviene usar según la pregunta de análisis.
#
# ## Qué voy a aprender
#
# Al finalizar este notebook usted podrá:
#
# - Crear gráficos de líneas, barras, dispersión e histogramas.
# - Identificar las partes de un gráfico: figura, ejes, título, etiquetas, escala, color, marcadores y leyenda.
# - Personalizar un gráfico para que comunique mejor una idea.
# - Usar `plt` para gráficos rápidos y `fig, ax` para gráficos más ordenados.
# - Leer un CSV con `pandas` y visualizar datos reales de nacimientos y defunciones.

# %% [markdown]
# ## Diagnóstico rápido
#
# Antes de ejecutar código, responda en una frase:
#
# 1. ¿Qué diferencia hay entre el eje X y el eje Y?
# 2. ¿Qué tipo de gráfico usaría para mostrar cambios durante varios años?
# 3. ¿Qué problema tiene un gráfico sin título ni etiquetas?

# %% [markdown]
# ## 1. Preparación
#
# Ejecute esta celda al inicio. Si alguna biblioteca no está instalada, use en una terminal:
#
# ```bash
# pip install matplotlib pandas
# ```

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-whitegrid")

# %% [markdown]
# ## 2. Primer gráfico de líneas
#
# **Concepto:** un gráfico de líneas permite observar cómo cambia una variable en una secuencia. Es muy útil para datos en el tiempo.
#
# **Pregunta guía:** ¿cómo cambiaron las ventas durante el primer semestre?
#
# **Prediga antes de ejecutar:** ¿en qué mes cree que la línea quedará más alta?

# %%
meses = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio"]
ventas = [120, 150, 135, 180, 210, 240]

#Grafico Solicitado  una grafica que compara el mes con las ventas con titulo y etiquetas en los ejes

plt.figure(figsize=(8, 4))

plt.plot(meses, ventas, marker='o', color='blue', linestyle='-', linewidth=2, markersize=8)
plt.legend(["Ventas Mensuales"])
plt.xlabel("Meses")
plt.ylabel("Ventas $")
plt.show()

# %%
meses = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio"]
ventas = [120, 150, 135, 180, 210, 240]
ventas_marzo = ventas.copy()
ventas_marzo[2] = 170  

#Grafico Solicitado  una grafica que compara el mes con las ventas con titulo y etiquetas en los ejes

plt.figure(figsize=(8, 4))

plt.plot(meses, ventas, marker='o', color='blue', linestyle='-',label='Ventas Primer Semestre')
plt.plot(meses, ventas_marzo, marker='s', color='orange', linestyle='--',label='Ventas Marzo Modificadas')    
plt.legend()
plt.title("Ventas Mensuales del Primer Semestre")
plt.xlabel("Meses")
plt.ylabel("Ventas $")
plt.show()

# %% [markdown]
# **Interpretación:** la línea permite ver una tendencia general de aumento, aunque marzo baja respecto a febrero.
#
# **Micro-reto:** cambie el valor de marzo a `170` y vuelva a ejecutar. ¿Cómo cambia la forma de la línea?

# %% [markdown]
# ## 3. Partes de un gráfico
#
# Un gráfico claro normalmente necesita:
#
# - **Figura:** espacio completo donde se dibuja.
# - **Ejes:** área donde aparecen los datos.
# - **Título:** indica la idea principal.
# - **Etiqueta del eje X:** explica la variable horizontal.
# - **Etiqueta del eje Y:** explica la variable vertical.
# - **Leyenda:** identifica cada serie cuando hay más de una.
# - **Escala:** define los valores visibles.

# %%
plt.plot(meses, ventas, marker="o", label="Ventas")

# %% [markdown]
# **Observe:** el gráfico comunica mejor porque ahora indica qué representa cada eje y qué significa la línea.
#
# **Micro-reto:** cambie el título para que sea más específico para una tienda o producto.

# %% [markdown]
# ## 4. Comparar dos series con leyenda
#
# **Concepto:** cuando se comparan dos grupos, la leyenda y los colores ayudan a distinguirlos.
#
# **Pregunta guía:** ¿cuál tienda vendió más en la mayoría de meses?

# %%
ventas_tienda_a = [120, 150, 135, 180, 210, 240]
ventas_tienda_b = [100, 130, 160, 170, 190, 230]
ventas_tienda_c = [110, 140, 150, 160, 200, 220]

plt.style.use("seaborn-v0_8-darkgrid")
plt.figure(figsize=(10, 5))
plt.plot(meses, ventas_tienda_a, marker="o", label="Tienda A")
plt.plot(meses, ventas_tienda_b, marker="s", label="Tienda B")
plt.plot(meses, ventas_tienda_c, marker="^", label="Tienda C")
plt.title("Comparación Mensual por Tienda")
plt.xlabel("Meses")
plt.ylabel("Ventas")
plt.tight_layout()
plt.legend()

plt.show()

# %% [markdown]
# **Interpretación:** la Tienda A tiene valores mayores en casi todos los meses, excepto marzo.
#
# **Micro-reto:** agregue una tercera tienda con una nueva lista llamada `ventas_tienda_c`.

# %% [markdown]
# ## 5. Límites, rotación y escala
#
# **Concepto:** los límites ayudan a enfocar la lectura, pero pueden cambiar la percepción del gráfico. Deben usarse con cuidado.
#
# **Pregunta guía:** ¿qué pasa si el eje Y empieza en 100 en lugar de 0?

# %%
plt.figure(figsize=(10, 5))
plt.plot(meses, ventas_tienda_a, marker="o",color="#27C5F5", label="Tienda A")

#Agragar limite vertical y Rotar etiquetas del eje x
limite_inferior = min(ventas_tienda_a) - 20
limite_superior = max(ventas_tienda_a) + 20

plt.ylim(limite_inferior, limite_superior)
plt.title("Ventas con límite vertical")
plt.xlabel("Mes")
plt.ylabel("Cantidad vendida")
plt.legend()
plt.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Reflexión:** limitar el eje Y puede hacer que los cambios parezcan más grandes. En reportes, explique cuando usa una escala recortada.
#
# **Micro-reto:** cambie `plt.ylim(100, 260)` por `plt.ylim(0, 260)` y compare.

# %% [markdown]
# ## 6. Estilos de línea y marcadores
#
# **Concepto:** los estilos permiten distinguir series y mejorar la lectura sin depender solo del color.

# %%
ventas_tienda_a = [120, 150, 135, 180, 210, 240]
ventas_tienda_b = [100, 130, 160, 170, 190, 230]
ventas_tienda_c = [110, 140, 150, 160, 200, 220]

plt.style.use("seaborn-v0_8-darkgrid")
plt.figure(figsize=(10, 5))
plt.plot(meses, ventas_tienda_a, marker="o", label="Tienda A", linestyle='-', color='#27C5F5')
plt.plot(meses, ventas_tienda_b, marker="s", label="Tienda B" ,linestyle='--', color="#27F527")
plt.plot(meses, ventas_tienda_c, marker="^", label="Tienda C",linestyle='--', color="#27F527")
plt.title("Comparación Mensual por Tienda")
plt.xlabel("Meses")
plt.ylabel("Ventas")
plt.tight_layout()
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 9
#       5 plt.style.use("seaborn-v0_8-darkgrid")
#       6 plt.figure(figsize=(10, 5))
#       7 plt.plot(meses, ventas_tienda_a, marker="o", label="Tienda A", linestyle='-', color='#27C5F5')
#       8 plt.plot(meses, ventas_tienda_b, marker="s", label="Tienda B" ,linestyle='--', color="#27F527")
# ----> 9 plt.plot(meses, ventas_tienda_c, marker="^", label="Tienda C",linestyle='---', color="#27F527")
#      10 plt.title("Comparación Mensual por Tienda")
#      11 plt.xlabel("Meses")
#      12 plt.ylabel("Ventas")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\pyplot.py:4043, in plot(scalex, scaley, data, *args, **kwargs)
#    4035 @_copy_docstring_and_deprecators(Axes.plot)
#    4036 def plot(
#    4037     *args: float | ArrayLike | str,
#    (...)   4041     **kwargs,
#    4042 ) -> list[Line2D]:
# -> 4043     return gca().plot(
#    4044         *args,
#    4045         scalex=scalex,
#    4046         scaley=scaley,
#    4047         **({"data": data} if data is not None else {}),
#    4048         **kwargs,
#    4049     )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\axes\_axes.py:1792, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1549 """
#    1550 Plot y versus x as lines and/or markers.
#    1551
#    (...)   1789 (``'green'``) or hex strings (``'#008000'``).
#    1790 """
#    1791 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1792 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1793 for line in lines:
#    1794     self.add_line(line)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\axes\_base.py:331, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     329     this += args[0],
#     330     args = args[1:]
# --> 331 yield from self._plot_args(
#     332     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     333     return_kwargs=return_kwargs
#     334 )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\axes\_base.py:554, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     552     return list(result)
#     553 else:
# --> 554     return [l[0] for l in result]
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\axes\_base.py:547, in <genexpr>(.0)
#     542 else:
#     543     raise ValueError(
#     544         f"label must be scalar or have the same length as the input "
#     545         f"data, but found {len(label)} for {n_datasets} datasets.")
# --> 547 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     548                       {**kwargs, 'label': label})
#     549           for j, label in enumerate(labels))
#     551 if return_kwargs:
#     552     return list(result)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\axes\_base.py:353, in _process_plot_var_args._make_line(self, axes, x, y, kw, kwargs)
#     351 kw = {**kw, **kwargs}  # Don't modify the original kw.
#     352 self._setdefaults(self._prop_cycle.getdefaults(kw), kw)
# --> 353 seg = mlines.Line2D(x, y, **kw)
#     354 return seg, kw
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\lines.py:374, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     371 self._dash_pattern = (0, None)  # offset, dash (scaled by linewidth)
#     373 self.set_linewidth(linewidth)
# --> 374 self.set_linestyle(linestyle)
#     375 self.set_drawstyle(drawstyle)
#     377 self._color = None
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\lines.py:1204, in Line2D.set_linestyle(self, ls)
#    1202 if ls in [' ', '', 'none']:
#    1203     ls = 'None'
# -> 1204 _api.check_in_list([*self._lineStyles, *ls_mapper_r], ls=ls)
#    1205 if ls not in self._lineStyles:
#    1206     ls = ls_mapper_r[ls]
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\_api\__init__.py:227, in check_in_list(values, **kwargs)
#     225     exists = False
#     226 if not exists:
# --> 227     raise ValueError(list_suggestion_error_msg(key, val, values))
#
# ValueError: '---' is not a valid value for ls. Did you mean one of: '--', '-'?

# %% [markdown]
# **Micro-reto:** cambie el estilo de línea de la Tienda B a `":"` y el marcador a `"^"`.

# %% [markdown]
# ## 7. Gráfico de barras
#
# **Cuándo usarlo:** cuando se comparan categorías, no una secuencia continua.
#
# **Pregunta guía:** ¿qué producto tuvo más unidades vendidas?

# %%
productos = ["Cuadernos", "Lápices", "Borradores", "Reglas"]
unidades = [85, 140, 60, 45]

# %% [markdown]
# **Interpretación:** los lápices son el producto con más unidades vendidas.
#
# **Micro-reto:** ordene visualmente los productos de mayor a menor creando nuevas listas ordenadas.

# %% [markdown]
# ## 8. Gráfico de dispersión
#
# **Cuándo usarlo:** cuando se quiere observar la relación entre dos variables numéricas.
#
# **Pregunta guía:** ¿parece haber relación entre horas de estudio y calificación?

# %%
horas_estudio = [1, 2, 2.5, 3, 4, 5, 6, 7]
calificaciones = [55, 62, 68, 70, 78, 84, 88, 95]

# %% [markdown]
# **Interpretación:** los puntos sugieren una relación positiva: cuando aumentan las horas de estudio, también sube la calificación.
#
# **Micro-reto:** agregue un estudiante con 8 horas de estudio y calificación 98.

# %% [markdown]
# ## 9. Histograma
#
# **Cuándo usarlo:** cuando se desea ver la distribución de una variable numérica.
#
# **Pregunta guía:** ¿en qué rango de edad hay más estudiantes?

# %%
edades = [18, 19, 19, 20, 21, 21, 22, 22, 22, 23, 24, 25, 27, 30]

# %% [markdown]
# **Micro-reto:** cambie `bins=5` por `bins=3` y luego por `bins=8`. ¿Cuál versión se entiende mejor?

# %% [markdown]
# ## 10. Errores comunes y cómo corregirlos
#
# El siguiente gráfico funciona, pero comunica mal porque no tiene contexto.

# %%
plt.plot(meses, ventas)
plt.show()

# %% [markdown]
# Una versión más clara agrega título, etiquetas, marcador y tamaño.

# %%
plt.figure(figsize=(8, 4))
plt.plot(meses, ventas, marker="o", color="tab:blue")
plt.title("Ventas mensuales del primer semestre")
plt.xlabel("Mes")
plt.ylabel("Cantidad vendida")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Subgráficos
#
# **Concepto:** los subgráficos permiten mostrar varias visualizaciones relacionadas en una misma figura.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(meses, ventas_tienda_a, marker="o", color="tab:blue")
axes[0].set_title("Ventas Tienda A")
axes[0].set_xlabel("Mes")
axes[0].set_ylabel("Cantidad vendida")
axes[0].tick_params(axis="x", rotation=45)

axes[1].bar(productos, unidades, color="tab:orange")
axes[1].set_title("Ventas por producto")
axes[1].set_xlabel("Producto")
axes[1].set_ylabel("Unidades")
axes[1].tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Micro-reto:** cambie la figura para que tenga 2 filas y 1 columna usando `plt.subplots(2, 1, figsize=(8, 8))`.

# %% [markdown]
# ## 12. Interfaz orientada a objetos: `fig` y `ax`
#
# Para trabajos más ordenados se recomienda crear `fig` y `ax`. Esta forma facilita personalizar y reutilizar gráficos.

# %%
fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(meses, ventas_tienda_a, marker="o", color="tab:blue", label="Tienda A")
ax.plot(meses, ventas_tienda_b, marker="s", color="tab:green", label="Tienda B")

ax.set_title("Ventas del primer semestre")
ax.set_xlabel("Mes")
ax.set_ylabel("Cantidad vendida")
ax.set_ylim(80, 260)
ax.legend()
ax.tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 13. Buenas prácticas visuales
#
# Use esta lista cada vez que termine un gráfico:
#
# - El título responde qué se está mostrando.
# - El eje X y el eje Y tienen etiquetas claras.
# - Si hay más de una serie, existe leyenda.
# - Los colores ayudan a comparar, no decoran sin propósito.
# - La escala no exagera ni oculta cambios importantes.
# - `plt.tight_layout()` evita que textos se corten.

# %% [markdown]
# ## 14. Aplicación con datos reales
#
# Ahora se usará el archivo `nacimientos_defunciones.csv`, ubicado en esta misma carpeta.
#
# **Pregunta guía:** ¿cómo han cambiado los nacimientos y las defunciones entre 1950 y 2021?

# %%
import pandas as pd

# %% [markdown]
# **Interpretación guiada:** observe si las líneas suben, bajan o se mantienen. También revise si la distancia entre nacimientos y defunciones cambia con el tiempo.
#
# **Micro-reto:** cree una columna llamada `Saldo Poblacional` restando `Defunciones` a `Nacimientos` y grafíquela.

# %% [markdown]
# ## Cierre
#
# Responda en su cuaderno o en una celda markdown:
#
# 1. ¿Qué tipo de gráfico usaría para comparar categorías?
# 2. ¿Qué tipo de gráfico usaría para ver cambios por año?
# 3. ¿Qué elemento visual le ayudó más a entender los datos?
# 4. ¿Qué duda le queda sobre Matplotlib?
