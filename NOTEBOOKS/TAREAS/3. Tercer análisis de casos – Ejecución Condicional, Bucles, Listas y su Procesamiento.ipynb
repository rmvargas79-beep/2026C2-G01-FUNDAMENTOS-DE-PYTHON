# %% [markdown]
# # Tarea Semana 07: Tercer Análisis de Casos
# ## Ejecución Condicional, Bucles, Listas y su Procesamiento
#
# **Valor:** 5%
# **Curso:** Fundamentos de Python
# **Nombre del estudiante:** Ronald Mauricio Vargas Villegas
# **Fecha:** 01/07/2026
#
# ### Objetivo general
# Resolver casos de análisis de datos aplicando ejecución condicional, ciclos de programación, listas, funciones simples y estructuras de datos básicas.
#
# ### Objetivos específicos
#
# 1. Analizar la utilización de la ejecución condicional de los algoritmos para el análisis de datos.
# 2. Analizar el comportamiento de los ciclos de programación en el diseño de algoritmos.
# 3. Integrar aprendizajes de las semanas 1 a 7: análisis del problema, entrada-proceso-salida, variables, condicionales, validación, indicadores, listas, ciclos, diccionarios simples y funciones.
#
# ### Contexto
# Esta tarea simula pequeñas situaciones de análisis de datos en Costa Rica. No se evalúa solo que el código funcione: también se evalúa que el estudiante pueda explicar el problema, elegir estructuras adecuadas, probar casos y justificar resultados.

# %% [markdown]
# ## Formato obligatorio para cada caso
#
# Complete las siguientes partes antes de escribir el código:
#
# 1. **Problema:** describa qué debe resolver el programa.
# 2. **Entrada / datos:** indique qué datos usa el algoritmo.
# 3. **Proceso:** explique qué cálculos, condiciones o ciclos se aplican.
# 4. **Salida esperada:** describa qué reporte o mensaje debe mostrar.
# 5. **Código:** escriba y ejecute la solución.
# 6. **Pruebas:** documente tres escenarios:
#    - caso normal;
#    - caso límite;
#    - caso inválido o situación especial.
#
# ### Reglas técnicas
#
# - Use nombres de variables descriptivos en `snake_case`.
# - Use `for` en los casos donde deba recorrer listas.
# - Use `if`, `elif` y `else` para clasificar resultados.
# - Use funciones simples cuando un cálculo se repita.
# - Use `try-except` cuando solicite datos numéricos al usuario.
# - No use Pandas, archivos externos, API real ni librerías no vistas en clase.
# - Puede usar `set` y tuplas solo como extensión breve cuando el caso lo indique.

# %% [markdown]
# ## Rúbrica de evaluación - 5%
#
# | Criterio | Valor |
# |---|---:|
# | Análisis del problema, entrada-proceso-salida y pruebas manuales | 1.0% |
# | Uso correcto de condicionales para clasificar o decidir | 1.0% |
# | Uso correcto de ciclos y listas para procesar varios datos | 1.0% |
# | Uso de funciones simples y estructuras adecuadas | 1.0% |
# | Claridad del reporte, interpretación y reflexión final | 1.0% |
#
# ### Penalizaciones posibles
#
# - Código que no ejecuta por errores de sintaxis: hasta -1.0%.
# - Variables con nombres ambiguos como `x`, `a`, `dato1`: hasta -0.5%.
# - No documentar pruebas: hasta -1.0%.
# - Copiar una solución sin explicación propia: según criterio docente.

# %% [markdown]
# ## Casos obligatorios
#
# | # | Caso | Descripción | Habilidades clave |
# |---|---|---|---|
# | 1 | Control de ventas diarias | Analiza ventas de una soda costarricense durante 5 días. | listas, `sum`, promedio, `if/elif/else` |
# | 2 | Asistencia a actividad cultural | Recorre asistencias y clasifica ocupación según capacidad. | ciclos, contadores, porcentajes |
# | 3 | Precios de feria | Procesa precios de productos y detecta valores altos o bajos. | listas, máximo, mínimo, rango, condiciones |
# | 4 | Reto integrador: Red EmprendeCR | Integra semanas 1 a 7 con lista de diccionarios, funciones, ciclos y reporte final. | funciones, listas, diccionarios, ciclos, condicionales |

# %% [markdown]
# ---
# # Caso 1: Control de ventas diarias de una soda
#
# ## Problema
# Una soda ubicada en San Pedro registra sus ventas de lunes a viernes. El programa debe calcular el total semanal, el promedio diario y clasificar el resultado según una meta.
#
# ## Entrada / datos
# Use esta lista base:
#
# ```python
# ventas_soda = [85000, 92000, 78000, 110000, 97000]
# meta_semanal = 450000
# ```
#
# ## Proceso esperado
#
# - Calcular total semanal.
# - Calcular promedio diario.
# - Comparar el total con la meta.
# - Clasificar:
#   - `Meta alcanzada` si el total es mayor o igual a la meta.
#   - `Cerca de la meta` si el total alcanza al menos el 80% de la meta.
#   - `Requiere atención` si no alcanza el 80%.
#
# ## Salida esperada
# Debe mostrar total, promedio, porcentaje de cumplimiento y estado final.
#
# ## Pruebas manuales
#
# | Escenario | Datos de entrada | Resultado esperado | Resultado obtenido |
# |---|---|---|---|
# | Caso normal | `[85000, 92000, 78000, 110000, 97000]`, meta `450000` | Meta alcanzada | |
# | Caso límite | total exactamente igual a la meta | Meta alcanzada | |
# | Caso especial | total menor al 80% de la meta | Requiere atención | |

# %%
# Caso 1 - Escriba su solución aquí
#Hecho por Ronald Mauricio Vargas Villegas

ventas_soda = [85000, 92000, 78000, 110000, 97000]
meta_semanal = 450000

# Complete el análisis

def imprimir_reporte(total_ventas,promedio_venta_diario,porcentaje_cumplimiento_ventas,meta,clasificacion):
    
    """Imprime el reporte final de ventas diarias de una soda"""
    print("REPORTE FINAL")
    print("-" * 50)
    print(meta)
    print(f"Las Ventas fueron de: {total_ventas}")
    print(f"El promerdio de Ventas diario es de: {promedio_venta_diario}")
    print(f"El porcentaje de Ventas cumplido es : {porcentaje_cumplimiento_ventas:.0f}")
    print(clasificacion)
    return "Buen Día"

total_ventas = 0
ventas_meta = 0
promedio_venta_diario = 0

for venta in ventas_soda:
    total_ventas += venta

promedio_venta_diario = (total_ventas / len(ventas_soda))
porcentaje_cumplimiento_ventas = (total_ventas / meta_semanal) * 100

if total_ventas >= meta_semanal:
    meta = (f"Meta Alcanzada")
    clasificacion = (f"La Sucursal esta funcionando Super bien")
elif porcentaje_cumplimiento_ventas >=80:
    meta = (f"Cerca de la meta")
    clasificacion = (f"La Sucursal esta cerca de la meta seguir trabajando para lograrlo")
else:
    meta = (f"No se Llego ni Cerca de la Meta")   
    clasificacion = (f"La Sucursal necesita atencion urgente para levantar sus ventas")
    
imprimir_reporte(total_ventas,promedio_venta_diario,porcentaje_cumplimiento_ventas,meta,clasificacion)
# Out:
# REPORTE FINAL
# --------------------------------------------------
# Meta Alcanzada
# Las Ventas fueron de: 462000
# El promerdio de Ventas diario es de: 92400.0
# El porcentaje de Ventas cumplido es : 103
# La Sucursal esta funcionando Super bien
# 'Buen Día'

# %% [markdown]
# ---
# # Caso 2: Asistencia a una actividad cultural
#
# ## Problema
# Una actividad cultural en Costa Rica registra asistencia por bloques horarios. El programa debe calcular la asistencia promedio y clasificar el nivel de ocupación.
#
# ## Entrada / datos
# Use esta lista base:
#
# ```python
# asistencias = [120, 180, 210, 250, 230]
# capacidad = 300
# ```
#
# ## Proceso esperado
#
# - Recorrer la lista con un ciclo `for`.
# - Calcular asistencia total y promedio.
# - Contar cuántos bloques superaron el 70% de capacidad.
# - Clasificar el promedio de ocupación:
#   - `Alta ocupación` si el promedio es mayor o igual al 80% de la capacidad.
#   - `Ocupación media` si el promedio es mayor o igual al 50%.
#   - `Baja ocupación` si el promedio es menor al 50%.
#
# ## Salida esperada
# Debe mostrar total de asistentes, promedio, bloques sobre 70% y estado de ocupación.
#
# ## Pruebas manuales
#
# | Escenario | Datos de entrada | Resultado esperado | Resultado obtenido |
# |---|---|---|---|
# | Caso normal | `[120, 180, 210, 250, 230]`, capacidad `300` | Ocupación Alta| Ocupación Alta Asis Tot 990 prome 198 Bloq con mas de 70%: 3 |
# | Caso límite | promedio exactamente 80% de capacidad | Alta ocupación | Ocupación Alta Asis Tot 1200 prome 240 Bloq con mas de 70%: 5 |
# | Caso especial | lista con asistencias muy bajas | Baja ocupación | Baja ocupación Asis Tot 510 prome 102 Bloq con mas de 70%: 0|

# %%
# Caso 2 - Escriba su solución aquí
#Hecho por Ronald Mauricio Vargas Villegas

#Definicion de Variables

#asistencias = [120, 180, 210, 250, 230]
asistencias = [240, 240, 240, 240, 240]
#asistencias = [120, 100, 80, 50, 160]
capacidad = 300
contador_bloques = 0
promedio_ocupacion = 0
asistencia_total = 0

# Complete el análisis procesando la infomacion proporcionada
for asistencia in asistencias:  
    asistencia_total = asistencia+asistencia_total
    if asistencia >= (capacidad * 0.7):
        contador_bloques += 1

promedio_asistencia = sum(asistencias)/len(asistencias)        
promedio_ocupacion = (promedio_asistencia / capacidad) * 100


if promedio_ocupacion >= 80:    
    mensaje = "Alta Ocupacion"
elif promedio_ocupacion >= 50:
    mensaje = "Ocupacion Media"
else:
    mensaje = "Baja Ocupacion"
    
"""Imprime el reporte final de Ocupacion."""
print("REPORTE FINAL")
print("-" * 50)
print(f"Asistentes Totales: {asistencia_total}")
print(f"Promedio de Asistencia: {promedio_asistencia:.0f}")
print(f"Promedio de Ocupacion: {promedio_ocupacion:.0f}")
print(f"Cuantos Bloques Ocuparon mas de un 70%: {contador_bloques}")
print(f"El Estado de Ocupacion fue: {mensaje}")
print("-" * 50)
# Out:
# REPORTE FINAL
# --------------------------------------------------
# Asistentes Totales: 1200
# Promedio de Asistencia: 240
# Promedio de Ocupacion: 80
# Cuantos Bloques Ocuparon mas de un 70%: 5
# El Estado de Ocupacion fue: Alta Ocupacion
# --------------------------------------------------

# %% [markdown]
# ---
# # Caso 3: Precios de productos de feria
#
# ## Problema
# Una persona compara precios de un mismo producto en diferentes ferias del agricultor. El programa debe analizar los precios y detectar si hay mucha variación.
#
# ## Entrada / datos
# Use esta lista base:
#
# ```python
# producto = "Tomate"
# precios = [900, 850, 1000, 950, 1200]
# ```
#
# ## Proceso esperado
#
# - Calcular precio promedio.
# - Identificar precio mínimo y máximo.
# - Calcular rango de precios: `máximo - mínimo`.
# - Clasificar la variación:
#   - `Variación alta` si el rango es mayor o igual a 300.
#   - `Variación moderada` si el rango es mayor o igual a 150.
#   - `Variación baja` si el rango es menor a 150.
# - Usar un ciclo para contar cuántos precios están por encima del promedio.
#
# ## Salida esperada
# Debe mostrar producto, promedio, mínimo, máximo, rango, precios sobre promedio y clasificación.
#
# ## Pruebas manuales
#
# | Escenario | Datos de entrada | Resultado esperado | Resultado obtenido |
# |---|---|---|---|
# | Caso normal | `[900, 850, 1000, 950, 1200]` | Variación alta | |
# | Caso límite | rango exactamente `300` | Variación alta | |
# | Caso especial | todos los precios iguales | Variación baja | |

# %%
# Caso 3 - Escriba su solución aquí
#Hecho por Ronald Mauricio Vargas Villegas
producto = "Tomate"
#precios = [900, 850, 1000, 950, 1200]
precios = [500, 500, 500, 500, 500]
#precios = [900, 850, 1000, 950, 1200]
# Definicion de Variables
precio_promedio = 0
precio_minimo = 0
precio_maximo = 0
total_precios = 0
precios_sobre_promedios = 0

precio_maximo = max(precios)
precio_minimo = min(precios)

# Procesamiento y logica del programa
#Se procede a calcular la variacion de precios del producto basado en la informacion sumistrada.
for precio in precios:
    total_precios = total_precios+precio
    

precio_promedio = total_precios/len(precios)

if precio_promedio >= 300:
    clasificacion_variacion = "Variación Alta"
elif precio_promedio >= 150:
    clasificacion_variacion = "Variación Moderada"
else:
    clasificacion_variacion = "Variación Baja"
    

for precio in precios:
    if precio >= precio_promedio:
        precios_sobre_promedios += 1



"""Imprime el reporte Final de Precios Producto."""
print("REPORTE FINAL")
print("-" * 50)
print(f"Producto: {producto}")
print(f"Promedio de Precio: {precio_promedio:}")
print(f"Precio Minimo: {precio_minimo}")
print(f"Precio Maximo: {precio_maximo}")
print(f"Cuantos precios por encima del promedio: {precios_sobre_promedios}")
print(f"Cuantos precios por encima del promedio: {clasificacion_variacion}")
print("-" * 50)
# Out:
# REPORTE FINAL
# --------------------------------------------------
# Producto: Tomate
# Promedio de Precio: 500.0
# Precio Minimo: 500
# Precio Maximo: 500
# Cuantos precios por encima del promedio: 5
# --------------------------------------------------

# %% [markdown]
# ---
# # Caso 4: Reto integrador - Red EmprendeCR
#
# ## Problema
# Una red de emprendimientos costarricenses desea analizar el desempeño semanal de varias sedes. Cada sede tiene nombre, provincia, tipo de negocio, ventas diarias y meta semanal.
#
# Este reto integra aprendizajes de las semanas 1 a 7:
#
# - Semana 1: comprensión del problema y algoritmo.
# - Semana 2: variables y entrada-proceso-salida.
# - Semana 3: decisiones con condicionales.
# - Semana 4: validación y código limpio.
# - Semana 5: indicadores para análisis de datos.
# - Semana 6: listas y ciclos.
# - Semana 7: listas de diccionarios, funciones y elección de estructuras.
#
# ## Datos base
#
# Use esta lista de diccionarios:
#
# ```python
# sedes = [
#     {
#         "nombre": "Soda San Pedro",
#         "provincia": "San José",
#         "tipo": "Alimentación",
#         "ventas": [85000, 92000, 78000, 110000, 97000],
#         "meta": 450000,
#     },
#     {
#         "nombre": "Panadería Cartago",
#         "provincia": "Cartago",
#         "tipo": "Panadería",
#         "ventas": [65000, 70000, 72000, 69000, 75000],
#         "meta": 380000,
#     },
#     {
#         "nombre": "Cafetería Liberia",
#         "provincia": "Guanacaste",
#         "tipo": "Cafetería",
#         "ventas": [98000, 105000, 99000, 120000, 115000],
#         "meta": 500000,
#     },
# ]
# ```
#
# ## Requisitos mínimos
#
# 1. Crear una función `calcular_total(ventas)`.
# 2. Crear una función `calcular_promedio(ventas)`.
# 3. Crear una función `clasificar_sede(total, meta)`.
# 4. Recorrer todas las sedes con un ciclo `for`.
# 5. Imprimir un reporte por sede con:
#    - nombre;
#    - provincia;
#    - total semanal;
#    - promedio diario;
#    - porcentaje de cumplimiento;
#    - estado.
# 6. Crear un `set` con las provincias presentes.
# 7. Crear una lista de tuplas `(nombre, total)` para guardar el ranking base.
# 8. Identificar la sede con mayor venta total.
#
# ## Clasificación requerida
#
# - `Meta alcanzada`: total mayor o igual a la meta.
# - `Cerca de la meta`: total mayor o igual al 80% de la meta.
# - `Requiere atención`: total menor al 80% de la meta.
#
# ## Salida esperada
# El reporte debe ser claro y comprensible para una persona que no está viendo el código.
#
# ## Pruebas manuales
#
# | Escenario | Datos de entrada | Resultado esperado | Resultado obtenido |
# |---|---|---|---|
# | Caso normal | datos base | Reporte para las 3 sedes | Reporte para las 3 sedes |
# | Caso límite | una sede con total igual a la meta | Meta alcanzada | Meta alcanzada |
# | Caso especial | una sede con ventas muy bajas | Requiere atención | Requiere atención |

# %%
# Caso 4 - Reto integrador
#Hecho por Ronald Mauricio Vargas Villegas
"""
#Caso promedio

sedes = [
    {
        "nombre": "Soda San Pedro",
        "provincia": "San José",
        "tipo": "Alimentación",
        "ventas": [85000, 92000, 78000, 110000, 97000],
        "meta": 450000,
    },
    {
        "nombre": "Panadería Cartago",
        "provincia": "Cartago",
        "tipo": "Panadería",
        "ventas": [65000, 70000, 72000, 69000, 75000],
        "meta": 380000,
    },
    {
        "nombre": "Cafetería Liberia",
        "provincia": "Guanacaste",
        "tipo": "Cafetería",
        "ventas": [98000, 105000, 99000, 120000, 115000],
        "meta": 500000,
    },
]

#Caso una sola que cumple
sedes = [
    {
        "nombre": "Soda San Pedro",
        "provincia": "San José",
        "tipo": "Alimentación",
        "ventas": [90000, 90000, 90000, 110000, 70000],
        "meta": 450000,
    }
]
"""

sedes = [
    {
        "nombre": "Soda San Pedro",
        "provincia": "San José",
        "tipo": "Alimentación",
        "ventas": [40000, 20000, 10000, 5000, 80000],
        "meta": 450000,
    }
]

# 1. Defina las funciones

reporte = []
lista_impresion = []
ranking = []
venta_mas_alta = 0

def calcular_total(ventas):
    """_Recibo una lista, la sumo y retorno el total.
    Args:
        ventas (list): Lista con las ventas del emprendimiento
    Returns:
        float: Sumatoria total de Ventas
    """
    venta_total_sede = sum(sede["ventas"])
    return venta_total_sede

def calcular_promedio(ventas):
    """_Recibo una lista, y calculo el promedio de ventas.
    Args:
        ventas (list): Lista con las ventas del emprendimiento
    Returns:
        float: Con el promedio total de Ventas
    """
    promedio_ventas = (sum(sede["ventas"])/len(sede["ventas"]))
    return promedio_ventas

def clasificar_sede(total, meta):
    """_Recibo el total de Ventas y la meta de las ventas.
    Args:
        total(int),meta(int).
    Returns:
        String: Con el mensaje dependiendo de la Clasificacion.
    """
    porcentaje = calcular_porcentaje(total, meta)
    if porcentaje >= 100:
        mensaje_sede = "Meta alcanzada."
    elif porcentaje >= 80:
        mensaje_sede = "Meta casi alcanzada, prestar atencion."
    else:
        mensaje_sede = "Meta no alcanzada URGE ATENCION"
    return mensaje_sede

def calcular_porcentaje(total,meta, formato = False):
    """_Recibo el total de Ventas y la meta de las ventas y calcula el porcentaje de las ventas.
    Args:
        total(int),meta(int) .
    Returns:
        float: Con el porcentaje de la meta alcanzadas.
    """
    porcentaje = total / meta * 100
    if formato:
        return f"{total / meta * 100:.2f}%"
    
    return porcentaje

def imprimir_reporte(lista_impresion):
    """_Recibo una lista y procedo a imprimir los valores en un formato mas claro y sencillo.
    Args:
        lista_impresion (list): Datos sin formatear para darles formato e imprimirlos
    Returns:
        float: Con el promedio total de Ventas
    """
    
    """Imprime el reporte final de ventas por sede."""
    print("REPORTE FINAL")
    print("-" * 50)

    for fila in lista_impresion:
        print(f"Sede: {fila['nombre']}")
        print(f"Provincia: {fila['provincia']}")
        print(f"Tipo: {fila['tipo']}")
        print(f"Total semanal: ₡{fila['total']:,.0f}")
        print(f"Promedio diario: ₡{fila['promedio']:,.0f}")
        print(f"Cumplimiento: {fila['porcentaje']}%")
        print(f"Estado: {fila['estado']}")
        print("-" * 50)    
        
        
        
    return reporte

def calcular_provincias(sedes):
    """_Recibo una lista de sedes y la proceso para tener los datos de las provincias.
    Args:
        sedes (list): Lista con la informacion de las sedes
    Returns:
        set: Con la informacion de las provincias
    """    
    provincias = set()
    for sede in sedes:
        provincias.add(sede["provincia"])          
    return provincias

def calcular_ingresos(sedes):
    """_Recibo una lista de sedes y la proceso para calcular las sedes con mayores ventas.
    Args:
        sedes (list): Lista con la informacion de las sedes
    Returns:
        list: Con la informacion de las sedes con ventas mas altas
    """ 
    sedes_mas_altas = []
    venta = 0    
    for sede in sedes:        
        if venta < sum(sede["ventas"]):
            venta= sum(sede["ventas"])
            sedes_mas_altas = [sede["nombre"]]
            sedes_mas_altas.append(sum(sede["ventas"]))
        elif venta == sum(sede["ventas"]):
            sedes_mas_altas.append(sede["nombre"])
            sedes_mas_altas.append(sum(sede["ventas"]))
    return sedes_mas_altas

def crear_tupla(nombre,total):
    """_Recibo el nombre de la sede y el total de ventas.
    Args:
        nombre(str),total(float): El nombre y total de ventas de las sedes.
    Returns:
        tupla: Con la informacion de la sede y el total de ventas
    """ 
    record = (nombre,total)    
    return record

# 2. Recorra las sedes y genere el reporte

for sede in sedes:
    #Aqui se procede a recorrer las sedes e ir obteniendo la informaciond de las mismas.
    #Para realizar el procesamiento se estara invocando las distintas funciones de manera que la informacion sea procesada.
    #Una vez este procesada se procede a la impresion del reporte llamando a la funcion respectiva.
    ventas = sede["ventas"]
    meta= sede["meta"]
    total_sede = calcular_total(ventas)
    promedio_sede = calcular_promedio(ventas)
    porcentaje= calcular_porcentaje(total_sede,meta,True)
    estado = clasificar_sede(total_sede,meta)
    ranking.append(crear_tupla(sede["nombre"], total_sede))

    if venta_mas_alta <= total_sede:
        venta_mas_alta = total_sede
        #agregar una lista de la sede
    
    lista_impresion.append(
        {
            "nombre": sede["nombre"],
            "provincia": sede["provincia"],
            "tipo": sede["tipo"],
            "total": total_sede,
            "promedio": promedio_sede,
            "porcentaje": porcentaje,
            "estado": estado,
        }
    )
    imprimir_reporte(lista_impresion)
    
    

# 3. Muestre provincias presentes, ranking base y mejor sede

print("Cantidad de sedes:", len(lista_impresion))
provincias = calcular_provincias(sedes)
print(f"Las Provincias Evaluadas son : {provincias}")
ventas_mayores = calcular_ingresos(sedes)
print(f"Las Sedes con Mayores ventas son:")
print(ventas_mayores)
print(f"El Historico de las Sedes es:")
print(ranking)
# Out:
# REPORTE FINAL
# --------------------------------------------------
# Sede: Soda San Pedro
# Provincia: San José
# Tipo: Alimentación
# Total semanal: ₡155,000
# Promedio diario: ₡31,000
# Cumplimiento: 34.44%%
# Estado: Meta no alcanzada URGE ATENCION
# --------------------------------------------------
# Cantidad de sedes: 1
# Las Provincias Evaluadas son : {'San José'}
# Las Sedes con Mayores ventas son:
# ['Soda San Pedro', 155000]
# El Historico de las Sedes es:
# [('Soda San Pedro', 155000)]

# %% [markdown]
# ---
# # Reflexión final
#
# Responda con sus propias palabras:
#
# 1. ¿Cuál caso le exigió pensar mejor la condición `if/elif/else`?
#     En realidad no fue muy dificil ya que por la practica poco a poco se acostumbra uno a
#     usar el if/elif/else cuando tiene que elegir entre opciones con operadores logicos.
# 2. ¿Para qué sirvió usar ciclos en lugar de repetir código manualmente?
#     Hace mucho mas simple y sencillo el codigo, no hay que escribir lo mismo varias veces.
#     Tambien hace el codigo mas limpio y sencillo de entender leer y arreglar
# 3. ¿Por qué el reto integrador usa una lista de diccionarios?
#     Por que los diccionarios es la forma que hasta ahora hemos visto que nos permite almacenar varias listas,
#     y distintos valores para poder usar con una etiqueta.
# 4. ¿Qué diferencia encontró entre lista, diccionario, tupla y set?
#     La tupla no se puede modificar eso le da el atributo de que no va a cambiar ni puede ser manipulada permitiendo que los datos
#     si asi uno lo quiere sean los mismos siempre en la ejecucion del programa.
#     EL set es muy util por que no permite valores duplicados.
#     La lista es super util por su versativilidad donde puede guardar valores de distintos tipos e incluso agregar repetidos,
#     no importa el orden y es 100% modificable.
#     Los diccionarios son super util por que tiene un indice o llave primaria como una base de datos y en un diccionario muy grande hace mas facil
#     localizar el dato que se esta buscando.
# 5. ¿Qué aprendió de las semanas 1 a 7 que pudo aplicar en esta tarea?
#     Literalmente todo, listas tipos de variables ciclos, if/elif/else, tuplas, ordenar el codigo, variables descriptivas, como documentar, la logica,
#     retener paciencia y revisar, leer y cuidar los errores de typo.
#
# ## Confirmación de entrega
#
# Antes de entregar, marque:
#
# - [X] Completé los cuatro casos.
# - [X] Ejecuté todas las celdas sin errores de sintaxis.
# - [X] Documenté pruebas manuales.
# - [X] Usé nombres de variables descriptivos.
# - [X] Escribí la reflexión final.
